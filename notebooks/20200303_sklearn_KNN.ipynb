# %% [markdown]
# # Module

# %%
import os 
import pandas as pd

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Config

# %%
data_dir = "../data/irs_data/"
train_file = 'iris_training.csv'
test_file = "iris_test.csv"

# Hyperparams for KNN
n_neighbors = 5

# %% [markdown]
# # Data

# %%
def get_iris_data(path, detail=False):
    df = pd.read_csv(path, skiprows=1, header=None)
    x = df[[0, 1, 2, 3]]
    y = df[[4]]
    if detail:
        print("x.info()")
        print(x.info())
        print("           ")
        print("x.head()")
        print(x.head())
    return x, y

# %%
train_x, train_y = get_iris_data(os.path.join(data_dir, train_file), detail=True)
# Out:
# x.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
# 0    120 non-null float64
# 1    120 non-null float64
# 2    120 non-null float64
# 3    120 non-null float64
# dtypes: float64(4)
# memory usage: 3.9 KB
# None
#
# x.head()
#      0    1    2    3
# 0  6.4  2.8  5.6  2.2
# 1  5.0  2.3  3.3  1.0
# 2  4.9  2.5  4.5  1.7
# 3  4.9  3.1  1.5  0.1
# 4  5.7  3.8  1.7  0.3

# %%
test_x, test_y = get_iris_data(os.path.join(data_dir, test_file), detail=True)
# Out:
# x.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
# 0    30 non-null float64
# 1    30 non-null float64
# 2    30 non-null float64
# 3    30 non-null float64
# dtypes: float64(4)
# memory usage: 1.1 KB
# None
#
# x.head()
#      0    1    2    3
# 0  5.9  3.0  4.2  1.5
# 1  6.9  3.1  5.4  2.1
# 2  5.1  3.3  1.7  0.5
# 3  6.0  3.4  4.5  1.6
# 4  5.5  2.5  4.0  1.3

# %% [markdown]
# # Model

# %%
model = KNeighborsClassifier(
#     n_neighbors=n_neighbors
)

# %% [markdown]
# # Train & Grid Search

# %%
k_range = list(range(1,10))
leaf_range = list(range(1,2))
weight_options = ['uniform','distance']
algorithm_options = ['auto','ball_tree','kd_tree','brute']
param_gridknn = dict(n_neighbors = k_range,weights = weight_options,algorithm=algorithm_options,leaf_size=leaf_range)

gridKNN = GridSearchCV(model,param_gridknn,cv=10,scoring='accuracy',verbose=1)
gridKNN.fit(
        X=train_x,
    y=train_y
)
print('best score is:',str(gridKNN.best_score_))
print('best params are:',str(gridKNN.best_params_))
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# /home/guohua/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/guohua/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/guohua/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# best score is: 0.975
# best params are: {'algorithm': 'auto', 'leaf_size': 1, 'n_neighbors': 4, 'weights': 'uniform'}

# %%
best_model = gridKNN.best_estimator_

# %% [markdown]
# # Eval

# %%
best_model.score(
    X=train_x,
    y=train_y
)
# Out:
# 0.9666666666666667

# %%
best_model.score(
    X=test_x,
    y=test_y
)
# Out:
# 0.9666666666666667

# %% [markdown]
# # Inference

# %%
sample = [
    [3.4, 5, 6, 3]
]

# %%
model.predict(
    X=sample
)
# Out:
# array([2])
